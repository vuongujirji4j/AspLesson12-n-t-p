-- %% [markdown]
-- # [dbo].[nhaxuatban]

-- %%
USE [sach_2210900085]
GO

-- %%
/****** Object:  Table [dbo].[nhaxuatban]    Script Date: 11/07/2024 8:29:28 SA ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[nhaxuatban](
	[manxb] [int] NOT NULL,
	[tennhaxuatban] [nvarchar](100) NULL,
	[tongdausach] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[manxb] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sach]

-- %%
/****** Object:  Table [dbo].[sach]    Script Date: 11/07/2024 8:29:29 SA ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sach](
	[masach] [int] NOT NULL,
	[tensach] [nvarchar](50) NULL,
	[sotrang] [int] NULL,
	[namxb] [int] NULL,
	[tentacgia] [nvarchar](50) NULL,
	[manxb] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[masach] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[nhaxuatban]

-- %%
INSERT [dbo].[nhaxuatban] ([manxb], [tennhaxuatban], [tongdausach]) VALUES (1, N'nhà xuất bản kim đồng', 2000)
INSERT [dbo].[nhaxuatban] ([manxb], [tennhaxuatban], [tongdausach]) VALUES (2, N'nhà xuất bản cnndvn', 2000)
GO

-- %% [markdown]
-- # [dbo].[sach]

-- %%
INSERT [dbo].[sach] ([masach], [tensach], [sotrang], [namxb], [tentacgia], [manxb]) VALUES (1, N'phan viết vượng', 102, 1940, N'phạm văn hiển', 1)
INSERT [dbo].[sach] ([masach], [tensach], [sotrang], [namxb], [tentacgia], [manxb]) VALUES (2, N'tự sát là tâm lý ', 104, 1870, N'nguyễn chí thiện ', 2)
INSERT [dbo].[sach] ([masach], [tensach], [sotrang], [namxb], [tentacgia], [manxb]) VALUES (3, N'mô côi', 100, 1709, N'nguyễn văn nam', 1)
GO

-- %% [markdown]
-- # [DF__nhaxuatba__tongd__37A5467C]

-- %%
ALTER TABLE [dbo].[nhaxuatban] ADD  DEFAULT ((0)) FOR [tongdausach]
GO

-- %% [markdown]
-- # [fk_sach_nhaxuatban]

-- %%
ALTER TABLE [dbo].[sach]  WITH CHECK ADD  CONSTRAINT [fk_sach_nhaxuatban] FOREIGN KEY([manxb])
REFERENCES [dbo].[nhaxuatban] ([manxb])
GO
ALTER TABLE [dbo].[sach] CHECK CONSTRAINT [fk_sach_nhaxuatban]
GO
